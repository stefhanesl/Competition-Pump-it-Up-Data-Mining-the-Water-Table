# %% [markdown]
# # <font color='gree'>**RESULTADOS**</font>

# %%
ruta_imagen = '/content/drive/MyDrive/Master DS/Machine Learning/TAREA/dataset/RESULTADOS.jpeg'

Image(filename=ruta_imagen)

# %% [markdown]
# <font color='blue'>**Resultados de Driven Data:**</font>
# Se corrieron varios modelos con el dataset de Pump it Up, Data Mining the Tanzania Water, de los cuales se mejoraron realizando normalizacion, haciendo un submuestreo de la clase mayoritaria y cambiando los hiperpametros; sin embargo, mejoraron en pocos puntos porcentuales en accuracy, los modelos utilizados fueron: Naive Bayes Gaussian, Decisioon Tree Classifier, KNN y Random Forest Classifier. En definitiva, el mejor modelo fue Random Forest Classifier que tuvo una precisión de 0.8115.

# %% [markdown]
# <font color='green'>**Comparando los dos modelos  de Random Forest Classifier**</font> En resumen, ambos resultados muestran que el modelo tiene dificultades para identificar correctamente la etiqueta 'functional needs repair', lo que podría ser un área de mejora en el futuro. Además, parece que ambos tienen un rendimiento similar en términos de precisión, recall y f1-score. Ambos modelos tienen una precisión promedio del 80%, lo que significa que el 80% de las predicciones realizadas por el modelo son correctas. También hay una similitud en las puntuaciones de recall y f1-score entre los modelos.

# %% [markdown]
# <font color='red'>**Resultados generales:**</font> En términos de precisión, recall y f1-score, el modelo de Random Forest parece tener el mejor rendimiento en general, con una precisión promedio del 80%, recall promedio del 67% y un f1-score promedio del 68%. Además, este modelo tiene la capacidad de manejar características no lineales y puede capturar interacciones entre características, lo que puede ser beneficioso para la clasificación de datos complejos.
#
# Sin embargo, el modelo KNN también tiene un rendimiento decente, con una precisión promedio del 77%, recall promedio del 62% y un f1-score promedio del 64%. Este modelo es relativamente fácil de entender e implementar, y puede ser útil para la clasificación de datos con patrones claros y distinciones entre las clases.
#
# Por otro lado, el modelo de Naive Bayes parece tener el peor rendimiento en términos de precisión, recall y f1-score. Este modelo puede ser limitado en su capacidad para capturar relaciones complejas entre características y puede no ser el mejor modelo para datos complejos.
#
# Finalmente, el modelo de Decision Tree también tiene un rendimiento decente, con una precisión promedio del 77%, recall promedio del 63% y un f1-score promedio del 65%. Este modelo puede ser útil para la interpretación y comprensión de los datos y puede ser especialmente efectivo para datos con características discretas.
#
# En resumen, en base a los resultados presentados, me inclinaría a elegir el modelo de Random Forest debido a su rendimiento general y su capacidad para manejar datos complejos. Sin embargo, cada modelo tiene sus ventajas y desventajas y es importante tener en cuenta las características específicas de los datos antes de tomar una decisión final.
